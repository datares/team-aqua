# %% [markdown]
# ## Data Cleaning for Further NLP of Product Catgory Variable

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
amazon_data = pd.read_csv('../Datasets/clean_amazon_data.csv').drop(columns = ['Unnamed: 0'])

# %%
amazon_data.columns
# Out:
# Index(['category', 'title', 'price', 'rating', 'No of reviews'], dtype='object')

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9972 entries, 0 to 9971
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       9972 non-null   object
#  1   title          9972 non-null   object
#  2   price          9972 non-null   float64
#  3   rating         9972 non-null   float64
#  4   No of reviews  9972 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 389.7+ KB

# %%
amazon_data.head()
# Out:
#                                             category  \
# 0  ['Kitchen & Dining', 'Kitchen Utensils & Gadge...
# 1  ['Health & Household', 'House Supplies', 'Hous...
# 2  ['Automotive', 'RV Parts & Accessories', ' Lig...
# 3  ['Toys & Games', 'Hobbies', 'Trains & Accessor...
# 4  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
#
#                                                title  price  rating  \
# 0  leifheit comfortline gourmet garlic slicer | f...  15.99     4.4
# 1  food grade mineral oil cutting boards countert...  19.80     4.9
# 2  srrb direct 1139 1383 led replacement r12 ba15...  15.99     4.4
# 3  bachmann industries 50 sliding door box santa ...  53.99     4.5
# 4  unisex cycling cap breathable anti-sweat helme...  29.95     4.0
#
#    No of reviews
# 0            403
# 1            321
# 2            321
# 3              9
# 4             11

# %%
amazon_data.columns = ['category', 'title', 'price', 'rating', 'num_reviews']
amazon_data
# Out:
#                                                category  \
# 0     ['Kitchen & Dining', 'Kitchen Utensils & Gadge...
# 1     ['Health & Household', 'House Supplies', 'Hous...
# 2     ['Automotive', 'RV Parts & Accessories', ' Lig...
# 3     ['Toys & Games', 'Hobbies', 'Trains & Accessor...
# 4     ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# ...                                                 ...
# 9967  ['Sports & Outdoors', 'Fan Shop', 'Home & Kitc...
# 9968  ['Beauty & Personal Care', 'Skin Care', ' Suns...
# 9969  ['Automotive', 'Performance Parts & Accessorie...
# 9970  ['Automotive', 'Performance Parts & Accessorie...
# 9971  ['Sports & Outdoors', 'Outdoor Recreation', 'S...
#
#                                                   title   price  rating  \
# 0     leifheit comfortline gourmet garlic slicer | f...   15.99     4.4
# 1     food grade mineral oil cutting boards countert...   19.80     4.9
# 2     srrb direct 1139 1383 led replacement r12 ba15...   15.99     4.4
# 3     bachmann industries 50 sliding door box santa ...   53.99     4.5
# 4     unisex cycling cap breathable anti-sweat helme...   29.95     4.0
# ...                                                 ...     ...     ...
# 9967                      gtei dallas cowboys desk lamp   39.99     4.1
# 9968  jergens 20938 natural glow instant sun body mo...   10.68     4.3
# 9969               arp 201-6303 connecting rod bolt kit    8.68     5.0
# 9970                        walker 31533 exhaust gasket   10.20     4.2
# 9971                           razor force drifter kart  329.00     4.0
#
#       num_reviews
# 0             403
# 1             321
# 2             321
# 3               9
# 4              11
# ...           ...
# 9967            6
# 9968         8185
# 9969            2
# 9970           55
# 9971          985
#
# [9972 rows x 5 columns]

# %%
amazon_data.iloc[0].title
# Out:
# 'leifheit comfortline gourmet garlic slicer | finely cut slice vegetableswhite red'

# %% [markdown]
# ## Formatting Category Variable For Easier Analysis

# %%
amazon_data['category'].dtype
# Out:
# dtype('O')

# %%
se = amazon_data['category'].iloc[0]
se
# Out:
# "['Kitchen & Dining', 'Kitchen Utensils & Gadgets', 'Graters, Peelers & Slicers', ' Mandolines & Slicers']"

# %%
def format_category(s):
    res = s[2:-2].replace("'", "").replace('"',"").split(", ")  # convert string to list 
    result = [s.strip() for s in res]           # noticed some leading and trailing whitespace in entries (see above cell)
    return set(result)                          # convert to set() for O(1) search

# %%
format_category(amazon_data['category'][1])
# Out:
# {'Health & Household',
#  'House Supplies',
#  'Household Cleaning',
#  'Waxes & Oils',
#  'Wood Conditioners'}

# %%
type(format_category(amazon_data['category'][1]))
# Out:
# set

# %%
amazon_data['clean_category'] = amazon_data['category'].apply(format_category)
amazon_data['clean_category']
# Out:
# 0       {Kitchen & Dining, Graters, Kitchen Utensils &...
# 1       {Waxes & Oils, Household Cleaning, House Suppl...
# 2          {Lighting, Automotive, RV Parts & Accessories}
# 3       {Toys & Games, Trains & Accessories, Boxcars, ...
# 4       {Outdoor Recreation, Caps, Sports & Outdoors, ...
#                               ...
# 9967    {Sports & Outdoors, Home & Kitchen, Fan Shop, ...
# 9968    {Sunscreens & Tanning Products, Beauty & Perso...
# 9969    {Bolts & Nuts, Performance Parts & Accessories...
# 9970    {Exhaust System, Gaskets, Automotive, Performa...
# 9971    {Accessories, Outdoor Recreation, Skates, Spor...
# Name: clean_category, Length: 9972, dtype: object

# %%
amazon_data
# Out:
#                                                category  \
# 0     ['Kitchen & Dining', 'Kitchen Utensils & Gadge...
# 1     ['Health & Household', 'House Supplies', 'Hous...
# 2     ['Automotive', 'RV Parts & Accessories', ' Lig...
# 3     ['Toys & Games', 'Hobbies', 'Trains & Accessor...
# 4     ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# ...                                                 ...
# 9967  ['Sports & Outdoors', 'Fan Shop', 'Home & Kitc...
# 9968  ['Beauty & Personal Care', 'Skin Care', ' Suns...
# 9969  ['Automotive', 'Performance Parts & Accessorie...
# 9970  ['Automotive', 'Performance Parts & Accessorie...
# 9971  ['Sports & Outdoors', 'Outdoor Recreation', 'S...
#
#                                                   title   price  rating  \
# 0     leifheit comfortline gourmet garlic slicer | f...   15.99     4.4
# 1     food grade mineral oil cutting boards countert...   19.80     4.9
# 2     srrb direct 1139 1383 led replacement r12 ba15...   15.99     4.4
# 3     bachmann industries 50 sliding door box santa ...   53.99     4.5
# 4     unisex cycling cap breathable anti-sweat helme...   29.95     4.0
# ...                                                 ...     ...     ...
# 9967                      gtei dallas cowboys desk lamp   39.99     4.1
# 9968  jergens 20938 natural glow instant sun body mo...   10.68     4.3
# 9969               arp 201-6303 connecting rod bolt kit    8.68     5.0
# 9970                        walker 31533 exhaust gasket   10.20     4.2
# 9971                           razor force drifter kart  329.00     4.0
#
#       num_reviews                                     clean_category
# 0             403  {Kitchen & Dining, Graters, Kitchen Utensils &...
# 1             321  {Waxes & Oils, Household Cleaning, House Suppl...
# 2             321     {Lighting, Automotive, RV Parts & Accessories}
# 3               9  {Toys & Games, Trains & Accessories, Boxcars, ...
# 4              11  {Outdoor Recreation, Caps, Sports & Outdoors, ...
# ...           ...                                                ...
# 9967            6  {Sports & Outdoors, Home & Kitchen, Fan Shop, ...
# 9968         8185  {Sunscreens & Tanning Products, Beauty & Perso...
# 9969            2  {Bolts & Nuts, Performance Parts & Accessories...
# 9970           55  {Exhaust System, Gaskets, Automotive, Performa...
# 9971          985  {Accessories, Outdoor Recreation, Skates, Spor...
#
# [9972 rows x 6 columns]

# %%
# amazon_data.to_csv('../Datasets/cleaned_data_nlp.csv')

# %%
categories = amazon_data['clean_category']

# %%
categories.describe()
# Out:
# count                                                  9972
# unique                                                 7482
# top       {Education & Crafts, Teachers Calendars & Plan...
# freq                                                      6
# Name: clean_category, dtype: object

# %% [markdown]
# ## Extracting and Examining Unique Category Values

# %%
category_list = set()
for cats in categories.values:
    category_list = category_list.union(cats)
category_list = sorted(list(category_list))

# %%
category_list = {}
for cats in categories.values:
    for c in cats:
        category_list[c] = category_list.setdefault(c, 0) + 1

# %%
category_list.items()
# Out:
# dict_items([('Kitchen & Dining', 447), ('Graters', 2), ('Kitchen Utensils & Gadgets', 83), ('Mandolines & Slicers', 1), ('Peelers & Slicers', 2), ('Waxes & Oils', 1), ('Household Cleaning', 20), ('House Supplies', 106), ('Health & Household', 539), ('Wood Conditioners', 1), ('Lighting', 9), ('Automotive', 1109), ('RV Parts & Accessories', 23), ('Toys & Games', 322), ('Trains & Accessories', 11), ('Boxcars', 2), ('Hobbies', 83), ('Train Cars', 4), ('Outdoor Recreation', 422), ('Caps', 8), ('Sports & Outdoors', 1390), ('Clothing', 1358), ('Cycling', 103), ('Computer Accessories & Peripherals', 50), ('Computers & Accessories', 155), ('Compressed Air Dusters', 2), ('Baby', 236), ('Diapering', 9), ('Pins & Fasteners', 1), ('Other Team Sports', 21), ('Roller Hockey', 2), ('Sports & Fitness', 840), ('Team Sports', 163), ('Tools & Home Improvement', 696), ('Handheld Flashlights', 1), ('Safety & Security', 47), ('Health Care', 116), ('Sleep Sound Machines', 1), ('Swimming', 6), ('Swimwear', 9), ('Poms', 1), ('Bean Bags & Footbags', 1), ('Sports & Outdoor Play', 29), ('Handlebars', 3), ('Parts & Components', 29), ('Parts', 103), ('Motorcycle & ATV', 150), ('Wiring Harnesses', 1), ('Rotors', 9), ('Bike Brakes & Parts', 11), ('Heaters', 2), ('Material Handling Products', 50), ('Industrial & Scientific', 886), ('Cables & Interconnects', 19), ('Ethernet Cables', 3), ('Shorts', 32), ('Soccer', 27), ('Nursery', 55), ('Bedding', 93), ('Bed Skirts', 3), ('Flatbreads', 2), ('Breads & Bakery', 36), ('Grocery & Gourmet Food', 505), ('Tool Kits', 2), ('Guest & Reception Chairs', 1), ('Office Furniture & Accessories', 23), ('Office Products', 322), ('Shoes & Jewelry', 1111), ('Blanket Sleepers', 6), ('Baby Girls', 47), ('Petite', 73), ('Women', 505), ('Dresses', 14), ('Shops', 347), ('Professional Dental Supplies', 32), ('Anesthesia Syringes & Needles', 1), ('Pipe Insulation', 2), ('Rough Plumbing', 30), ('Lawn & Garden', 289), ('Patio', 289), ('Outdoor Heating', 8), ('Conduits & Fittings', 3), ('Electrical Boxes', 3), ('Electrical', 75), ('Tom-Tom Drumheads', 1), ('Musical Instruments', 262), ('Instrument Accessories', 139), ('Drum & Percussion Accessories', 25), ('Drum Set Accessories', 8), ('Percolators', 1), ('Coffee', 23), ('Home & Kitchen', 542), ('Tea & Espresso', 13), ('Crafts & Sewing', 271), ('Craft Supplies', 78), ('Arts & Crafts Tape', 3), ('Arts', 271), ('Chocolate', 2), ('Pantry Staples', 261), ('Jarred & Packaged Foods', 37), ('Dry Soup Mixes', 1), ('Canned', 43), ('Pet Supplies', 255), ('Treats', 8), ('Cats', 58), ('Baby Care', 21), ('Skin Care', 39), ('Grooming', 15), ('More Systems', 20), ('Sony PSP', 8), ('Video Games', 88), ('Job Site Lighting', 1), ('Fishing', 58), ('Baits & Attractants', 14), ('Lures', 14), ('Hunting & Fishing', 171), ('Freeze-Dried Food', 3), ('Camping & Hiking', 75), ('Office Supplies', 204), ('Tag Fasteners & Bag Seals', 1), ('Switches & Relays', 38), ('Air Temperature', 1), ('Replacement Parts', 507), ('Staples', 2), ('Fasteners', 52), ('Livestock Health Supplies', 1), ('Farm & Ranch', 13), ('Faceplates', 3), ('Accessories', 351), ('Protectors & Skins', 3), ('Nintendo Switch', 5), ('Leg Warmers', 2), ('Shoes', 100), ('Tennis & Racquet Sports', 23), ('Footwear', 15), ('Leisure Sports & Game Room', 81), ('Cabinets', 6), ('Game Boy Color', 1), ('Gun Accessories', 26), ('Maintenance & Storage', 26), ('Gun & Ammunition Storage & Safes', 4), ('Shooting', 48), ('Gun Racks', 3), ('Toys & Game Room', 3), ('Fan Shop', 127), ('Sewing Notions & Supplies', 23), ('Sewing', 61), ('Sharps', 1), ('Exotic Apparel', 12), ('Novelty & More', 83), ('Milling Accessories', 8), ('Cutting Tools', 27), ('Chamfer', 1), ('Measure & Inspect', 77), ('Test', 77), ('Turbidity Meters', 1), ('Novelties', 3), ('Professional Medical Supplies', 68), ('Apparel', 10), ('Professional Apparel', 1), ('Cooking & Baking', 70), ('Brazil Nuts', 1), ('Mosaic Making', 1), ('Boys', 114), ('Suits', 5), ('Beauty & Personal Care', 226), ('Shave & Hair Removal ...

# %%
category_df = pd.DataFrame.from_dict(category_list.items())
category_df.columns = ['category', 'frequency']
category_df.head()
# Out:
#                      category  frequency
# 0            Kitchen & Dining        447
# 1                     Graters          2
# 2  Kitchen Utensils & Gadgets         83
# 3        Mandolines & Slicers          1
# 4           Peelers & Slicers          2

# %%
category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6656 entries, 0 to 6655
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   category   6656 non-null   object
#  1   frequency  6656 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 104.1+ KB

# %%
category_df.sort_values('frequency', ascending = False, inplace = True, ignore_index = True)
category_df
# Out:
#                      category  frequency
# 0           Sports & Outdoors       1390
# 1                    Clothing       1358
# 2             Shoes & Jewelry       1111
# 3                  Automotive       1109
# 4     Industrial & Scientific        886
# ...                       ...        ...
# 6651           Cylinder Hoses          1
# 6652         Guiders & Wedges          1
# 6653    Infant & Toddler Beds          1
# 6654     Compression Bandages          1
# 6655             Bolts & Nuts          1
#
# [6656 rows x 2 columns]

# %% [markdown]
# ## Top Categories

# %%
print(category_df['category'].values[0:5])
# Out:
# ['Sports & Outdoors' 'Clothing' 'Shoes & Jewelry' 'Automotive'
#  'Industrial & Scientific']

# %% [markdown]
# ## Average Review by Category

# %%
'Graters' in amazon_data['clean_category']
# Out:
# False

# %%
amazon_data['clean_category'].apply(lambda x: 'Graters' in x)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9967    False
# 9968    False
# 9969    False
# 9970    False
# 9971    False
# Name: clean_category, Length: 9972, dtype: bool

# %%
amazon_data[amazon_data['clean_category'].apply(lambda x: 'Graters' in x)]['rating']
# Out:
# 0       4.4
# 1081    2.8
# Name: rating, dtype: float64

# %%
amazon_data[amazon_data['clean_category'].apply(lambda x: 'Graters' in x)][['price', 'rating']].mean()
# Out:
# price     10.97
# rating     3.60
# dtype: float64

# %%
for i in category_df.index:
    row = category_df.loc[i]
    category = row['category']
    contains_category = amazon_data['clean_category'].apply(lambda x: category in x)
   
    category_df.at[i, 'avg_rating'] =  amazon_data[contains_category]['rating'].mean()

# %%
category_df
# Out:
#                      category  frequency  avg_rating
# 0           Sports & Outdoors       1390    4.376691
# 1                    Clothing       1358    4.347054
# 2             Shoes & Jewelry       1111    4.341404
# 3                  Automotive       1109    4.411903
# 4     Industrial & Scientific        886    4.429684
# ...                       ...        ...         ...
# 6651           Cylinder Hoses          1    4.400000
# 6652         Guiders & Wedges          1    4.000000
# 6653    Infant & Toddler Beds          1    4.700000
# 6654     Compression Bandages          1    4.700000
# 6655             Bolts & Nuts          1    5.000000
#
# [6656 rows x 3 columns]

# %% [markdown]
# ## Average value for multiple variables at once by category

# %%
def store_average_value(category_df, variables):
    
    var_names = ["avg_"+var for var in variables]
    
    for i in category_df.index:
        row = category_df.loc[i]        # row in df corresponding to category
        category = row['category']      # category name 
        contains_category = amazon_data['clean_category'].apply(lambda x: category in x)    # does the product fall in the category?
        category_df.loc[i, var_names] =  amazon_data[contains_category][variables].mean().values  # if so, average the variables we desire

    return category_df

# %%
category_df = store_average_value(category_df, ['price', 'rating'])

# %%
category_df
# Out:
#                      category  frequency  avg_rating   avg_price
# 0           Sports & Outdoors       1390    4.376691   49.290036
# 1                    Clothing       1358    4.347054   36.191775
# 2             Shoes & Jewelry       1111    4.341404   36.406724
# 3                  Automotive       1109    4.411903   59.004734
# 4     Industrial & Scientific        886    4.429684   54.669944
# ...                       ...        ...         ...         ...
# 6651           Cylinder Hoses          1    4.400000   27.030000
# 6652         Guiders & Wedges          1    4.000000  179.990000
# 6653    Infant & Toddler Beds          1    4.700000  100.485000
# 6654     Compression Bandages          1    4.700000   18.340000
# 6655             Bolts & Nuts          1    5.000000    8.680000
#
# [6656 rows x 4 columns]

# %%
category_df = store_average_value(category_df, ['num_reviews'])
category_df.head(5)
# Out:
#                   category  frequency  avg_rating  avg_price  avg_num_reviews
# 0        Sports & Outdoors       1390    4.376691  49.290036       436.865468
# 1                 Clothing       1358    4.347054  36.191775       648.265832
# 2          Shoes & Jewelry       1111    4.341404  36.406724       682.820882
# 3               Automotive       1109    4.411903  59.004734       173.338142
# 4  Industrial & Scientific        886    4.429684  54.669944       286.321670

# %%
# category_df.to_csv('../Category-Centric-Datasets/category_data.csv')

# %% [markdown]
# ### Preliminary Visualizations

# %%
category_df[0:10]
# Out:
#                    category  frequency  avg_rating  avg_price  avg_num_reviews
# 0         Sports & Outdoors       1390    4.376691  49.290036       436.865468
# 1                  Clothing       1358    4.347054  36.191775       648.265832
# 2           Shoes & Jewelry       1111    4.341404  36.406724       682.820882
# 3                Automotive       1109    4.411903  59.004734       173.338142
# 4   Industrial & Scientific        886    4.429684  54.669944       286.321670
# 5          Sports & Fitness        840    4.361905  47.842202       427.984524
# 6  Tools & Home Improvement        696    4.436207  54.722457       523.718391
# 7            Home & Kitchen        542    4.422878  60.060018      1361.575646
# 8        Health & Household        539    4.369202  28.081596       979.669759
# 9         Replacement Parts        507    4.450888  48.707623       104.149901

# %%
import matplotlib.ticker as ticker

# %%
fig, axes = plt.subplots(1, 2)
category_df[0:10][['category','avg_price']].plot.bar(x="category", rot = 90, ylabel = "Average Price", xlabel = "Category", ax = axes[0], legend = False)
category_df[0:10][['category','avg_rating']].plot.bar(x="category", rot = 90, ylabel = "Average Rating", xlabel = "Category", ax = axes[ 1], legend = False)
fig.tight_layout()
plt.show()
